# %%
# %pip install ultralytics -q
# %pip install --upgrade --force-reinstall "numpy<2" -q

# %%
import sys
sys.path.append('/kaggle/input/car-damage-detection-code')  

from src.train import train_model

# %%
train_model()

# %%
# !zip -r models_output.zip /kaggle/working/models
